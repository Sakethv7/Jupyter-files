# %% [markdown]
# Saketh Velidimalla
# IFT- 533. Monday- Wednesday
# 1225618875

# %%
from bokeh.plotting import figure, show
import pandas as pd

l4= pd.read_csv("C:/Users/saket/Desktop/IFT 533/adult.data", header = None)

l4
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
from bokeh.plotting import figure, show, output_notebook
from math import pi
from bokeh.models import SingleIntervalTicker, LinearAxis

output_notebook()

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

p = figure(x_range=fruits, height=350, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, width=0.9)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.y_range.start = 0

p.yaxis.minor_tick_line_color = None

p.xaxis.major_label_orientation = pi/4

ticker = SingleIntervalTicker(interval=5, num_minor_ticks=0)
xaxis = LinearAxis(ticker=ticker)
p.add_layout(xaxis, 'below')

# Corrected the typo here - use 'ticker' instead of 'Interviw'
ticker2 = SingleIntervalTicker(interval=2, num_minor_ticks=0)
yaxis = LinearAxis(ticker=ticker2)
p.add_layout(yaxis, 'left')

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ba6f0e27-643d-4145-a6cb-5120912be194">Loading BokehJS ...</span>
#     </div>
#   <div id="eee7c72f-3f1a-4993-a998-933188f33863" data-root-id="p1001" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show, output_notebook
from math import pi
from bokeh.models import LabelSet, ColumnDataSource

output_notebook()

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

p = figure(x_range=fruits, height= 450, title ='fruit Counts', 
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, width=0.9)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.y_range.start = 0

p.yaxis.minor_tick_line_color = None

p.xaxis.major_label_orientation = pi/4

src = ColumnDataSource(
    data=dict(xvals=['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'],
              yvals=[5, 3, 4, 2, 4, 6],
              text=[5, 3, 4, 2, 4, 6]
              )
)

lbls = LabelSet(x='xvals', y='yvals', text='text', source=src, y_offset=5, x_offset=-2)

p.add_layout(lbls)
p.yaxis.visible = False

p.outline_line_color = None
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fd5875ba-1f6d-4836-a84d-8000fbff355e">Loading BokehJS ...</span>
#     </div>
#   <div id="f216fe3e-fcf9-4b3c-a3b6-f0a0fb6db0d4" data-root-id="p1043" style="display: contents;"></div>

# %%
x=[]
y=[]

data_counts = {}
for data_label in l4.iloc[:,-1]:
    if data_label in data_counts:
        data_counts[data_label] += 1
    else:
        data_counts[data_label]=1

x = list(data_counts.keys()) 

y = list(data_counts.values())  

print(x,y)
# Out:
# [' <=50K', ' >50K'] [24720, 7841]

# %%
p = figure(x_range=x, width=400,  height=350, title="Income Counts",)

p.vbar(x=x, top=y, width=0.5)


show(p)
# Out:
#   <div id="d0eda160-4016-4a45-bb88-a9fc261635f4" data-root-id="p1082" style="display: contents;"></div>

# %%
km = pd.read_csv("C:/Users/saket/Desktop/IFT 533/kobe_bryant_points.csv", header = 0)

km
# Out:
#        Year   PTS
# 0   1996-97   539
# 1   1997-98  1220
# 2   1998-99   996
# 3   1999-00  1485
# 4   2000-01  1938
# 5   2001-02  2019
# 6   2002-03  2461
# 7   2003-04  1557
# 8   2004-05  1819
# 9   2005-06  2832
# 10  2006-07  2430
# 11  2007-08  2323
# 12  2008-09  2201
# 13  2009-10  1970
# 14  2010-11  2078
# 15  2011-12  1616
# 16  2012-13  2133
# 17  2013-14    83
# 18  2014-15   782
# 19  2015-16  1161

# %%
from bokeh.plotting import figure, show, output_notebook

output_notebook()

X_label = km['Year'].tolist()
Points = km['PTS'].tolist()
 
l= figure(x_range= X_label, width=1000, height=400, title="Kobe Bryant's Points Over the Years")
l.line(X_label,Points, line_width=2)


show(l)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cfb437d9-6c95-4bfa-bf6b-d4f0770f6bcc">Loading BokehJS ...</span>
#     </div>
#   <div id="fb750436-7d10-4a47-b351-80a6d9d6699f" data-root-id="p1121" style="display: contents;"></div>

# %%
from math import pi
p = figure(width=1000, height=400, x_range=km['Year'].astype(str).tolist(), title="Kobe Bryant's Points Over the Years")

p.xaxis.major_label_orientation = pi/4

p.line(x=km['Year'].astype(str), y=km['PTS'], line_width=2)


output_notebook()
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ff3f1a93-7f6e-4ecd-a8cc-503d54b73ebc">Loading BokehJS ...</span>
#     </div>
#   <div id="e2078d64-6de6-4b4c-8db1-62977329c0d3" data-root-id="p1160" style="display: contents;"></div>

# %%
l2 =figure(x_range= X_label, width=1000, height=400, title="Kobe Bryant's Points Over the Years")
l2.circle(X_label, Points, size = 10)
show(l2)
# Out:
#   <div id="ecc84e96-8a69-4ef1-b674-019e26da3717" data-root-id="p1200" style="display: contents;"></div>

# %%
p =figure(x_range= X_label, width=1000, height=400, title="Kobe Bryant's Points Over the Years")
p.square(X_label, Points, size = 10)
show(p)
# Out:
#   <div id="f7e0df05-b35b-4a71-abe1-d9b749995e07" data-root-id="p1239" style="display: contents;"></div>
