# %%
from bokeh.plotting import figure, show
import pandas as pd

l4= pd.read_csv("C:/Users/saket/Desktop/IFT 533/adult.data", header = None)

l4
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
#Data Ink maximization steps

#1) 
from bokeh.plotting import figure, show, output_notebook
from math import pi
output_notebook()

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

p = figure(x_range=fruits, height=350, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, width=0.9)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.y_range.start = 0

p.yaxis.minor_tick_line_color= None

p.xaxis.major_label_orientation = pi/4

p.outline_line_color = None   

#To set the x axis range, use a Range1D object to set the required range:


show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="db034304-00a0-4913-9eea-a4b8d3a836ac">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1009 (INCOMPATIBLE_SCALE_AND_RANGE): A Scale is incompatible with one or more ranges on the same plot dimension: incompatibility on x-dimension: Range1d(id='p1289', ...), CategoricalScale(id='p1268', ...) [figure(id='p1257', ...)]
#   <div id="d70183f6-307d-4e35-b6ec-0d6a2627c672" data-root-id="p1257" style="display: contents;"></div>

# %%
#2) 
from bokeh.models import Label
lbl = Label(x='Apples', y=5, x_units='screen', y_units='screen',
                   text="ABC" , render_mode='css',
                   border_line_color='black', border_line_alpha=1.0,
                   background_fill_color='white', background_fill_alpha=1.0)
f.add_layout(lbl)
